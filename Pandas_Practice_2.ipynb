# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshulmohan27/Python_Everything/blob/main/Pandas_Practice_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("muhammadmusharraf444/used-car-price-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'used-car-price-prediction-dataset' dataset.
# Path to dataset files: /kaggle/input/used-car-price-prediction-dataset

# %%
import pandas as pd
import os

for file in os.listdir(path):
  print(file)

df = pd.read_csv(os.path.join(path, "quikr_car.csv"))
df.head(10) #displays first 10 rows
# Out:
# quikr_car.csv
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# 5        Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
# 6                               Ford Figo      Ford  2012       1,75,000
# 7                             Hyundai Eon   Hyundai  2013       1,90,000
# 8        Ford EcoSport Ambiente 1.5L TDCi      Ford  2016       8,30,000
# 9          Maruti Suzuki Alto K10 VXi AMT    Maruti  2015       2,50,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# ...

# %%
df.shape #rows and columns
# Out:
# (892, 6)

# %%
df.columns #name of columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df.dtypes #columns type
# Out:
# name          object
# company       object
# year          object
# Price         object
# kms_driven    object
# fuel_type     object
# dtype: object

# %%
df.describe()
# Out:
#               name company  year          Price  kms_driven fuel_type
# count          892     892   892            892         840       837
# unique         525      48    61            274         258         3
# top     Honda City  Maruti  2015  Ask For Price  45,000 kms    Petrol
# freq            13     235   117             35          30       440

# %%
df.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df[df['fuel_type']=='Diesel'] #all diesel cars
# Out:
#                                    name   company  year          Price  \
# 1               Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 4      Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# 5      Ford EcoSport Titanium 1.5L TDCi      Ford  2015  Ask For Price
# 6                             Ford Figo      Ford  2012       1,75,000
# 8      Ford EcoSport Ambiente 1.5L TDCi      Ford  2016       8,30,000
# ..                                  ...       ...   ...            ...
# 876                 Maruti Suzuki Dzire    Maruti  2016       4,50,000
# 880  Maruti Suzuki Swift Dzire Tour VDi    Maruti  2009       2,50,000
# 885           Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 888                 Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                  Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#      kms_driven fuel_type
# 1        40 kms    Diesel
# 4    36,000 kms    Diesel
# 5    59,000 kms    Diesel
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce').astype('Int64')

# %%
df["Price"]
# Out:
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
#        ...
# 887    <NA>
# 888    <NA>
# 889    <NA>
# 890    <NA>
# 891    <NA>
# Name: Price, Length: 892, dtype: Int64

# %%
df[df['name'].str.contains('maruti', case=False, na=False)]
# Out:
#                                       name company  year  Price  kms_driven  \
# 2               Maruti Suzuki Alto 800 Vxi  Maruti  2018   <NA>  22,000 kms
# 9           Maruti Suzuki Alto K10 VXi AMT  Maruti  2015   <NA>  60,000 kms
# 11              Maruti Suzuki Stingray VXi  Maruti  2015   <NA>  30,000 kms
# 19                  Maruti Suzuki Alto 800  Maruti  2014   <NA>  35,550 kms
# 22              Maruti Suzuki Alto 800 Vxi  Maruti  2015   <NA>  39,000 kms
# ..                                     ...     ...   ...    ...         ...
# 876                    Maruti Suzuki Dzire  Maruti  2016   <NA>   2,500 kms
# 879          Maruti Suzuki Alto LXi BS III  Maruti  2005   <NA>  65,000 kms
# 880     Maruti Suzuki Swift Dzire Tour VDi  Maruti  2009   <NA>  51,000 kms
# 882  Maruti Suzuki Alto 800 Select Variant  Maruti  2015   <NA>  70,000 kms
# 883             Maruti Suzuki Ritz VXI ABS  Maruti  2011   <NA>  50,000 kms
#
#     fuel_type
# 2      Petrol
# 9      Petrol
# ...

# %%
df[(df['fuel_type'] == 'Petrol') & (df['kms_driven']>50000)] #would have worked if kms_driven were in numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5878/300299955.py in <cell line: 0>()
# ----> 1 df[(df['fuel_type'] == 'Petrol') & (df['kms_driven']>50000)]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
# ...

# %%
df.loc[df['year'].idxmin()]
# Out:
# name          9 SEATER MAHINDRA BOL
# company                           9
# year                           , Ac
# Price                          <NA>
# kms_driven                      NaN
# fuel_type                       NaN
# Name: 799, dtype: object

# %%
df['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'I', 'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Commercial', 'MARUTI', 'Force', 'Mercedes', 'Land', 'Yamaha',
#        'selling', 'URJENT', 'Swift', 'Used', 'Jaguar', 'Jeep', 'tata',
#        'Sale', 'very', 'Volvo', 'i', '2012', 'Well', 'all', '7', '9',
#        'scratch', 'urgent', 'sell', 'TATA', 'Any', 'Tara'], dtype=object)

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
df['company'].value_counts()
# Out:
# company
# Maruti        235
# Hyundai       145
# Mahindra      100
# Tata           74
# Honda          61
# Toyota         39
# Chevrolet      35
# Renault        34
# Ford           31
# Volkswagen     20
# Skoda          13
# Audi           11
# Mini            8
# Datsun          8
# BMW             8
# Mitsubishi      6
# Mercedes        6
# Nissan          6
# Commercial      6
# Force           4
# Fiat            4
# I               3
# Hindustan       3
# tata            3
# Jaguar          2
# Used            2
# Sale            2
# MARUTI          2
# urgent          2
# URJENT          1
# Land            1
# Yamaha          1
# Jeep            1
# Swift           1
# selling         1
# very            1
# i               1
# 2012            1
# Well            1
# Volvo           1
# all             1
# 7               1
# 9               1
# scratch         1
# sell            1
# TATA            1
# Any             1
# Tara            1
# Name: count, dtype: int64

# %%
df['company'].value_counts().sort_values(ascending = False).head(5)
# Out:
# company
# Maruti      235
# Hyundai     145
# Mahindra    100
# Tata         74
# Honda        61
# Name: count, dtype: int64

# %%
df.groupby('fuel_type')['kms_driven'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...

# %%
df.groupby('year').size()
# Out:
# year
# , Ac    1
# ...     3
# /-Rs    1
# 150k    1
# 1995    2
#        ..
# t xe    1
# tion    1
# ture    1
# zest    1
# zire    1
# Length: 61, dtype: int64

# %%
df['kms_driven'] = (
    df['kms_driven']
    .str.replace(',', '').str.replace('kms','')
)

# %%
df['kms_driven'] = pd.to_numeric(
    df['kms_driven'],
    errors='coerce'
)

# %%
df['kms_driven'].head()
# Out:
# 0    45000.0
# 1       40.0
# 2    22000.0
# 3    28000.0
# 4    36000.0
# Name: kms_driven, dtype: float64

# %%
df["most_driven"]=df.groupby('company')['kms_driven'].rank(method = 'dense', ascending=False)
df[df['most_driven']==2]
# Out:
#                                                   name     company  year  \
# 47                                    Datsun Redi GO S      Datsun  2017
# 49             Mitsubishi Pajero Sport Limited Edition  Mitsubishi  2015
# 73                                   Mini Cooper S 1.6        Mini  2013
# 74                                    Datsun Redi GO S      Datsun  2017
# 94                                   BMW 3 Series 320i         BMW  2011
# 189                                  Mini Cooper S 1.6        Mini  2013
# 218                Force Motors Force One LX ABS 7 STR       Force  2015
# 229            Mitsubishi Pajero Sport Limited Edition  Mitsubishi  2015
# 246                Force Motors Force One LX ABS 7 STR       Force  2015
# 249                                      Mini Cooper S        Mini  2013
# 270                           Nissan Terrano XL D Plus      Nissan  2015
# 272                    Renault Duster 85 PS RxE Diesel     Renault  2014
# ...
